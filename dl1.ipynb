# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("D:/Training Datasets/Boston.csv")
data
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
data.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
data.head(n=10)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm    age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3
# 5           6  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3
# 6           7  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5
# 7           8  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5
# 8           9  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5
# 9          10  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2
# 5  222     18.7  394.12   5.21  28.7
# 6  311     15.2  395.60  12.43  22.9
# 7  311     15.2  396.90  19.15  27.1
# 8  311     15.2  386.63  29.93  16.5
# 9  311     15.2  386.71  17.10  18.9

# %%
data.shape
# Out:
# (506, 15)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
data.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# std      0.702617   28.148861    2.105710    8.707259  168.537116    2.164946
# min      3.561000    2.900000    1.129600    1.000000  187.000000   12.600000
# 25%      5.885500   45.025000    2.100175    4.000000  279.000000   17.400000
# 50%      6.208500   77.500000    3.207450    5.000000  330.000000   19.050000
# 75%      6.623500   94.075000    5.188425   24.000000  666.000000   20.200000
# max      8.780000  100.000000   12.126500   24.000000  711.000000   22.000000
#
#             black       lstat        medv
# count  506.000000  506.000000  506.000000
# mean   356.674032   12.653063   22.532806
# std     91.294864    7.141062    9.197104
# min      0.320000    1.730000    5.000000
# 25%    375.377500    6.950000   17.025000
# 50%    391.440000   11.360000   21.200000
# 75%    396.225000   16.955000   25.000000
# max    396.900000   37.970000   50.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
import seaborn as sns

# %%
sns.histplot(data["medv"])
# Out:
# <Axes: xlabel='medv', ylabel='Count'>

# %%
sns.boxplot(data["medv"])
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
# Split the data into input and output variables
X = data.drop('medv', axis=1)
y =data['medv']
# Scale the input features 
scaler =StandardScaler()
X_train =scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
# Splitthe data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print('Training set shape:', X_train.shape, y_train.shape)
print('Testing set shape:', X_test.shape, y_test.shape)
# Out:
# Training set shape: (354, 14) (354,)
# Testing set shape: (152, 14) (152,)

# %%
from keras.models import Sequential 
from keras.layers import Dense, Dropout

# %%
# Define the model architecture
model = Sequential()
model.add(Dense(128,activation = 'relu',input_dim =14))
model.add(Dense(64,activation = 'relu'))
model.add(Dense(32,activation = 'relu'))
model.add(Dense(16,activation = 'relu'))
model.add(Dense(1))

# %%
# Display the model summary
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1920
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 12801 (50.00 KB)
# Trainable params: 12801 (50.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Compile the model
model.compile(optimizer = 'adam',loss ='mean_squared_error',metrics=['mae'])

x_val=X_train
y_val=y_train

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 1s 811ms/step - loss: 3507.1226 - mae: 58.3430 - val_loss: 1406.5219 - val_mae: 35.9443
# Epoch 2/20
# 1/1 [==============================] - 0s 31ms/step - loss: 1406.5219 - mae: 35.9443 - val_loss: 481.1541 - val_mae: 18.7025
# Epoch 3/20
# 1/1 [==============================] - 0s 34ms/step - loss: 481.1541 - mae: 18.7025 - val_loss: 214.0186 - val_mae: 12.2129
# Epoch 4/20
# 1/1 [==============================] - 0s 32ms/step - loss: 214.0186 - mae: 12.2129 - val_loss: 257.9790 - val_mae: 12.1996
# Epoch 5/20
# 1/1 [==============================] - 0s 35ms/step - loss: 257.9790 - mae: 12.1996 - val_loss: 333.5067 - val_mae: 13.8664
# Epoch 6/20
# 1/1 [==============================] - 0s 34ms/step - loss: 333.5067 - mae: 13.8664 - val_loss: 371.8226 - val_mae: 14.8539
# Epoch 7/20
# 1/1 [==============================] - 0s 37ms/step - loss: 371.8225 - mae: 14.8539 - val_loss: 362.5418 - val_mae: 14.7685
# Epoch 8/20
# 1/1 [==============================] - 0s 34ms/step - loss: 362.5418 - mae: 14.7685 - val_loss: 322.7545 - val_mae: 13.9326
# Epoch 9/20
# 1/1 [==============================] - 0s 36ms/step - loss: 322.7545 - mae: 13.9326 - val_loss: 278.7278 - val_mae: 12.8425
# Epoch 10/20
# 1/1 [==============================] - 0s 33ms/step - loss: 278.7278 - mae: 12.8425 - val_loss: 240.5096 - val_mae: 11.8006
# Epoch 11/20
# 1/1 [==============================] - 0s 32ms/step - loss: 240.5096 - mae: 11.8006 - val_loss: 208.4192 - val_mae: 10.9395
# Epoch 12/20
# 1/1 [==============================] - 0s 32ms/step - loss: 208.4192 - mae: 10.9395 - val_loss: 182.0342 - val_mae: 10.2919
# Epoch 13/20
# 1/1 [==============================] - 0s 32ms/step - loss: 182.0342 - mae: 10.2919 - val_loss: 163.1309 - val_mae: 10.0031
# Epoch 14/20
# 1/1 [==============================] - 0s 31ms/step - loss: 163.1309 - mae: 10.0031 - val_loss: 151.2077 - val_mae: 9.8107
# Epoch 15/20
# 1/1 [==============================] - 0s 30ms/step - loss: 151.2077 - mae: 9.8107 - val_loss: 144.3908 - val_mae: 9.5847
# Epoch 16/20
# 1/1 [==============================] - 0s 32ms/step - loss: 144.3908 - mae: 9.5847 - val_loss: 140.2098 - val_mae: 9.3380
# Epoch 17/20
# 1/1 [==============================] - 0s 29ms/step - loss: 140.2098 - mae: 9.3380 - val_loss: 136.4538 - val_mae: 9.0237
# Epoch 18/20
# 1/1 [==============================] - 0s 32ms/step - loss: 136.4538 - mae: 9.0237 - val_loss: 131.2504 - val_mae: 8.6458
# Epoch 19/20
# 1/1 [==============================] - 0s 31ms/step - loss: 131.2504 - mae: 8.6458 - val_loss: 123.8722 - val_mae: 8.2241
# Epoch 20/20
# 1/1 [==============================] - 0s 30ms/step - loss: 123.8722 - mae: 8.2241 - val_loss: 114.5688 - val_mae: 7.7416

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 82.3654 - mae: 6.3567

# %%
predictions = model.predict(X_test)

print("Actual vs Predicted Values:")
results = pd.DataFrame({'Actual': y_test, 'Predicted': predictions.flatten()})
print(results)

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Actual', y='Predicted', data=results, alpha=0.7)
plt.title('Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()
# Out:
# 5/5 [==============================] - 0s 2ms/step
# Actual vs Predicted Values:
#      Actual  Predicted
# 173    23.6  16.975874
# 274    32.4  21.078636
# 491    13.6  20.270844
# 72     22.8  14.469972
# 452    16.1  18.738619
# ..      ...        ...
# 441    17.1  18.736172
# 23     14.5  13.776615
# 225    50.0  17.008669
# 433    14.3  14.853984
# 447    12.6  18.845709
#
# [152 rows x 2 columns]

# %%
print(*zip(predictions,y_test))
# Out:
# (array([16.975874], dtype=float32), 23.6) (array([21.078636], dtype=float32), 32.4) (array([20.270844], dtype=float32), 13.6) (array([14.469972], dtype=float32), 22.8) (array([18.738619], dtype=float32), 16.1) (array([16.733744], dtype=float32), 20.0) (array([19.121124], dtype=float32), 17.8) (array([17.840773], dtype=float32), 14.0) (array([19.035397], dtype=float32), 19.6) (array([22.622145], dtype=float32), 16.8) (array([17.071508], dtype=float32), 21.5) (array([13.079244], dtype=float32), 18.9) (array([12.603854], dtype=float32), 7.0) (array([16.157429], dtype=float32), 21.2) (array([19.457138], dtype=float32), 18.5) (array([18.723686], dtype=float32), 29.8) (array([16.386793], dtype=float32), 18.8) (array([18.30751], dtype=float32), 10.2) (array([21.705065], dtype=float32), 50.0) (array([18.990826], dtype=float32), 14.1) (array([22.002754], dtype=float32), 25.2) (array([20.93927], dtype=float32), 29.1) (array([12.742726], dtype=float32), 12.7) (array([24.906994], dtype=float32), 22.4) (array([17.560715], dtype=float32), 14.2) (array([17.982964], dtype=float32), 13.8) (array([16.043488], dtype=float32), 20.3) (array([14.698562], dtype=float32), 14.9) (array([17.000023], dtype=float32), 21.7) (array([22.620378], dtype=float32), 18.3) (array([16.778236], dtype=float32), 23.1) (array([20.0695], dtype=float32), 23.8) (array([19.77677], dtype=float32), 15.0) (array([19.444431], dtype=float32), 20.8) (array([17.55584], dtype=float32), 19.1) (array([14.117526], dtype=float32), 19.4) (array([13.77556], dtype=float32), 34.7) (array([22.86799], dtype=float32), 19.5) (array([16.722515], dtype=float32), 24.4) (array([13.801235], dtype=float32), 23.4) (array([22.257435], dtype=float32), 19.7) (array([21.526794], dtype=float32), 28.2) (array([22.299017], dtype=float32), 50.0) (array([14.975152], dtype=float32), 17.4) (array([16.08851], dtype=float32), 22.6) (array([19.369333], dtype=float32), 15.1) (array([12.893128], dtype=float32), 13.1) (array([14.049233], dtype=float32), 24.2) (array([18.968613], dtype=float32), 19.9) (array([13.557141], dtype=float32), 24.0) (array([13.442335], dtype=float32), 18.9) (array([21.452852], dtype=float32), 35.4) (array([13.767352], dtype=float32), 15.2) (array([17.134558], dtype=float32), 26.5) (array([18.971315], dtype=float32), 43.5) (array([19.053818], dtype=float32), 21.2) (array([19.041813], dtype=float32), 18.4) (array([22.59863], dtype=float32), 28.5) (array([16.596634], dtype=float32), 23.9) (array([17.384869], dtype=float32), 18.5) (array([15.765731], dtype=float32), 25.0) (array([18.403862], dtype=float32), 35.4) (array([16.277428], dtype=float32), 31.5) (array([11.640563], dtype=float32), 20.2) (array([17.17147], dtype=float32), 24.1) (array([16.830723], dtype=float32), 20.0) (array([19.30286], dtype=float32), 13.1) (array([16.404797], dtype=float32), 24.8) (array([16.859173], dtype=float32), 30.8) (array([14.777881], dtype=float32), 12.7) (array([15.772656], dtype=float32), 20.0) (array([19.189987], dtype=float32), 23.7) (array([15.954137], dtype=float32), 10.8) (array([20.007753], dtype=float32), 20.6) (array([16.016502], dtype=float32), 20.8) (array([18.952534], dtype=float32), 5.0) (array([17.634502], dtype=float32), 20.1) (array([22.34948], dtype=float32), 48.5) (array([19.419296], dtype=float32), 10.9) (array([19.226149], dtype=float32), 7.0) (array([14.972833], dtype=float32), 20.9) (array([17.117044], dtype=float32), 17.2) (array([20.35606], dtype=float32), 20.9) (array([19.089417], dtype=float32), 9.7) (array([19.455463], dtype=float32), 19.4) (array([16.008352], dtype=float32), 29.0) (array([16.716887], dtype=float32), 16.4) (array([20.588821], dtype=float32), 25.0) (array([16.89714], dtype=float32), 25.0) (array([18.613733], dtype=float32), 17.1) (array([16.335718], dtype=float32), 23.2) (array([13.508372], dtype=float32), 10.4) (array([18.844753], dtype=float32), 19.6) (array([17.069454], dtype=float32), 17.2) (array([18.83862], dtype=float32), 27.5) (array([18.537663], dtype=floa ...
